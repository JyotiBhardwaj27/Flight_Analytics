# %% [markdown]
# # AIRPORTS DATA INGESTION PIPELINE

# %% [markdown]
# ###1️⃣ Import Required Libraries
#
# Purpose:
# Load all Python libraries needed for API calls, data handling, and rate-limit safety.

# %%
import requests
import pandas as pd
import time

# %% [markdown]
# ### 2️⃣ Define API Configuration & Airport List
#
# Purpose:
# Centralize API credentials and define the list of airports used throughout the project.

# %%
API_HOST = "aerodatabox.p.rapidapi.com"
HEADERS = {
    "x-rapidapi-key": "784d49518dmsh0343e5da9ef1c6ap18e96bjsn12a30dc8b692",
    "x-rapidapi-host": API_HOST
}
AIRPORTS = [
    "DEL","BOM","BLR","HYD","MAA","CCU","COK",
    "JFK","LHR","DXB","SIN","CDG","HND","SYD"
]

# %% [markdown]
# ### 3️⃣ Fetch Basic Airport Identity (IATA Endpoint)
#
# Endpoint Used:
# /airports/iata/{iata}
#
# Purpose:
# Retrieve authoritative airport identifiers, coordinates, and timezone.

# %%
import pandas as pd
import requests

rows = []

for code in AIRPORTS:
    url = f"https://aerodatabox.p.rapidapi.com/airports/iata/{code}"
    r = requests.get(url, headers=HEADERS)

    if r.status_code != 200:
        print(f"❌ {code} failed | Status: {r.status_code}")
        print(r.text)
        continue

    d = r.json()

    location = d.get("location", {})
    country = location.get("country", {})

    rows.append({
        "icao_code": d.get("icao"),
        "iata_code": d.get("iata"),
        "name": d.get("shortname"),
        "city": location.get("city"),
        "country": country.get("name"),
        "continent": country.get("continent"),
        "latitude": location.get("lat"),
        "longitude": location.get("lon"),
        "timezone": d.get("timeZone")
    })

# %% [markdown]
# ### 4️⃣ Create Initial Airport DataFrame
#
# Purpose:
# Convert raw API responses into a structured Pandas DataFrame.

# %%
airport_df = pd.DataFrame(rows)
airport_df
# Out:
#    icao_code iata_code  name  city country continent   latitude   longitude  \
# 0       VIDP       DEL  None  None    None      None  28.566500   77.103100
# 1       VABB       BOM  None  None    None      None  19.088700   72.867900
# 2       VOBL       BLR  None  None    None      None  13.197899   77.706300
# 3       VOHS       HYD  None  None    None      None  17.231318   78.429855
# 4       VOMM       MAA  None  None    None      None  12.990005   80.169300
# 5       VECC       CCU  None  None    None      None  22.654700   88.446700
# 6       VOCI       COK  None  None    None      None  10.152000   76.401900
# 7       KJFK       JFK  None  None    None      None  40.639800  -73.778900
# 8       EGLL       LHR  None  None    None      None  51.470600   -0.461941
# 9       OMDB       DXB  None  None    None      None  25.252798   55.364400
# 10      WSSS       SIN  None  None    None      None   1.350190  103.994000
# 11      LFPG       CDG  None  None    None      None  49.012800    2.549999
# 12      RJTT       HND  None  None    None      None  35.552300  139.780000
# 13      YSSY       SYD  None  None    None      None -33.946100  151.177000
#
#             timezone
# 0       Asia/Kolkata
# 1       Asia/Kolkata
# 2       Asia/Kolkata
# 3       Asia/Kolkata
# 4       Asia/Kolkata
# 5       Asia/Kolkata
# 6       Asia/Kolkata
# 7   America/New_York
# 8      Europe/London
# 9         Asia/Dubai
# 10    Asia/Singapore
# 11      Europe/Paris
# 12        Asia/Tokyo
# 13  Australia/Sydney

# %% [markdown]
# ### 5️⃣ Define Country-to-Continent Mapping
#
# Purpose:
# Map ISO country codes to continents for analytical classification.

# %%
COUNTRY_TO_CONTINENT = {
    "IN": "Asia",
    "US": "North America",
    "GB": "Europe",
    "AE": "Asia",
    "SG": "Asia",
    "FR": "Europe",
    "JP": "Asia",
    "AU": "Australia"
}

# %% [markdown]
# ### 6️⃣ Enrich Airport Metadata Using Search Endpoint
#
# Endpoint Used:
# /airports/search/location
#
# Purpose:
# Enrich airport records with:
#
# - Airport name
#
# - City (municipality)
#
# - Country code
#
# - Continent (derived)

# %%
import requests
import time

def enrich_airport_by_location(lat, lon):
    url = "https://aerodatabox.p.rapidapi.com/airports/search/location"

    params = {
        "lat": lat,
        "lon": lon,
        "radiusKm": 10,
        "limit": 1
    }

    r = requests.get(url, headers=HEADERS, params=params)

    if r.status_code != 200:
        return None, None, None,None

    data = r.json()
    items = data.get("items", [])

    if not items:
        return None, None, None,None

    item = items[0]
    name = item.get("name") or item.get("shortName")
    city = item.get("municipalityName")
    country_code = item.get("countryCode")
    continent = COUNTRY_TO_CONTINENT.get(country_code)

    return name,city, country_code, continent

# %% [markdown]
# ### 7️⃣ Apply Enrichment to All Airports
#
# Purpose:
# Iteratively enrich each airport using its latitude and longitude.

# %%
names = []
cities = []
countries = []
continents = []

for _, row in airport_df.iterrows():
    name, city, country_code, continent = enrich_airport_by_location(
        row["latitude"],
        row["longitude"]
    )
    names.append(name)
    cities.append(city)
    countries.append(country_code)
    continents.append(continent)

    time.sleep(1)  # IMPORTANT: avoid rate limiting

# %% [markdown]
# ### 8️⃣ Merge Enriched Fields into Airport DataFrame
#
# Purpose:
# Create a final, analytics-ready airport master table.

# %%
airport_df["name"] = names
airport_df["city"] = cities
airport_df["country"] = countries
airport_df["continent"] = continents

airport_df
# Out:
#    icao_code iata_code                                 name       city  \
# 0       VIDP       DEL              New Delhi Indira Gandhi  New Delhi
# 1       VABB       BOM           Mumbai Chhatrapati Shivaji     Mumbai
# 2       VOBL       BLR                  Bangalore Bengaluru  Bangalore
# 3       VOHS       HYD               Hyderabad Rajiv Gandhi  Hyderabad
# 4       VOMM       MAA                              Chennai    Chennai
# 5       VECC       CCU  Kolkata Netaji Subhash Chandra Bose    Kolkata
# 6       VOCI       COK                         Kochi Cochin      Kochi
# 7       KJFK       JFK              New York John F Kennedy   New York
# 8       EGLL       LHR                      London Heathrow     London
# 9       OMDB       DXB                                Dubai      Dubai
# 10      WSSS       SIN                     Singapore Changi  Singapore
# 11      LFPG       CDG              Paris Charles de Gaulle      Paris
# 12      RJTT       HND                                Tokyo      Tokyo
# 13      YSSY       SYD               Sydney Kingsford Smith     Sydney
#
#    country      continent   latitude   longitude          timezone
# 0       IN           Asia  28.566500   77.103100      Asia/Kolkata
# 1       IN           Asia  19.088700   72.867900      Asia/Kolkata
# 2       IN           Asia  13.197899   77.706300      Asia/Kolkata
# 3       IN           Asia  17.231318   78.429855      Asia/Kolkata
# 4       IN           Asia  12.990005   80.169300      Asia/Kolkata
# 5       IN           Asia  22.654700   88.446700      Asia/Kolkata
# 6       IN           Asia  10.152000   76.401900      Asia/Kolkata
# 7       US  North America  40.639800  -73.778900  America/New_York
# 8       GB         Europe  51.470600   -0.461941     Europe/London
# 9       AE           Asia  25.252798   55.364400        Asia/Dubai
# 10      SG           Asia   1.350190  103.994000    Asia/Singapore
# 11      FR         Europe  49.012800    2.549999      Europe/Paris
# 12      JP           Asia  35.552300  139.780000        Asia/Tokyo
# 13      AU      Australia -33.946100  151.177000  Australia/Sydney

# %%
airport_df.to_csv("../data/airports.csv", index=False)
